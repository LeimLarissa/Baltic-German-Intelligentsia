# %%
import re
import pandas as pd
import numpy as np
import csv
from pathlib import Path

# %% [markdown]
# ## Try Outs

# %%
#https://sparkbyexamples.com/pandas/pandas-add-row-to-dataframe/
new_row = {'YEAR': '1873', 'SOCIETY': 'GEG', 'NUM_NomSpace_ERROR': 109, 'NUM_SpecSpace_ERROR': 130}         #I want the dictionary to be the outcome of my function
df = df.append(new_row, ignore_index=True) #ignore_index=True)                                                      #I add the row to the existing df outside of the function
df
# Out:
# /tmp/ipykernel_343/1586408101.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True) #ignore_index=True)                                                      #I add the row to the existing df outside of the function
#    YEAR SOCIETY NUM_NomSpace_ERROR NUM_SpecSpace_ERROR
# 0   NaN     NaN                NaN                 NaN
# 1  1873     GEG                109                 130

# %%
#https://www.data-science-architect.de/spalten-zeilen-erstellen-loeschen-und-sortieren-in-pandas/
#index retrieved from: https://medium.com/@petehouston/set-index-for-dataframe-in-pandas-55400e306e42
#index = [x for x in range(0, len(df.values)+1)]

new_row_df = pd.DataFrame({'YEAR': '1874', 'SOCIETY': 'GGuA', 'NUM_NomSpace_ERROR': 109, 'NUM_SpecSpace_ERROR': 130},     #I create a new df to merge with the existing one. 
                                                                                                                          #I still need a dictionary as the outcome of my function
                          index = [len(df.values)+1],                                                                     #Same as in original df
                          columns = ['YEAR', 'SOCIETY', 'NUM_NomSpace_ERROR', 'NUM_SpecSpace_ERROR'])                     #Same as in original df

df = pd.concat([df, new_row_df])                                                                                          #I merge the exisitng df with the new_row df 
df
# Out:
#    YEAR SOCIETY NUM_NomSpace_ERROR NUM_SpecSpace_ERROR
# 1   NaN     NaN                NaN                 NaN
# 2  1874    GGuA                109                 130

# %%
new_row_df = pd.DataFrame({'YEAR': '1875', 'SOCIETY': 'GGuA', 'NUM_NomSpace_ERROR': 109, 'NUM_SpecSpace_ERROR': 130}, 
                          index = [len(df.values) +1], 
                          columns = ['YEAR', 'SOCIETY', 'NUM_NomSpace_ERROR', 'NUM_SpecSpace_ERROR'])

df = pd.concat([df, new_row_df])

df
# Out:
#    YEAR SOCIETY NUM_NomSpace_ERROR NUM_SpecSpace_ERROR
# 1   NaN     NaN                NaN                 NaN
# 2  1874    GGuA                109                 130
# 3  1875    GGuA                109                 130

# %%
year = '1903'
society = 'GEG'
sourcedir = 'Sources/' + society + '/' + year + '_' + society + '_SB.txt'

# %%
new_row_df = pd.DataFrame(add_Space_E_Stats(year, society, sourcedir),                                                                                                          
                          index = [len(df.values)+1],                                                
                          columns = ['YEAR', 'SOCIETY', 'NUM_NomSpace_ERROR', 'NUM_SpecSpace_ERROR'])
df = pd.concat([df, new_row_df])

# %%
find_NomSpace_E(year, society, sourcedir, short_mode=True)
find_SpecSpace_E(year, society, sourcedir, short_mode=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [6], line 1
# ----> 1 find_NomSpace_E(year, society, sourcedir, short_mode=True)
#       2 find_SpecSpace_E(year, society, sourcedir, short_mode=True)
#
# NameError: name 'year' is not defined

# %%
print(ov_md[1][1])
# Out:
# GEG

# %% [markdown]
# ## Functions

# %%
def find_NomSpace_E(year, society, sourcedir, short_mode=True):
    '''
    This function takes the (str)year and (str)society abbreviation as well as a file directory and gives out the number of overall errors in short_mode. 
    In long mode it also shows the erroneus lines that have spaces between letters and double space between words.
    '''
    
    with open(sourcedir, 'r') as fp:                                  #I open the file as read(!)
        file = fp.readlines()                                         #I copy all lines from the file in a list
    
    findings = []                                                     #an empty list where I collect the line numbers of the error findings
    
    for num, line in enumerate(file, 1):                              #I go through each line of the file-list while also counting the lines starting by 1 instead of 0
        if re.match('^\S\s\S\s.*  ', line):                           #I search for the regex marking a none-white space followed by a white space (repeated once to eliminate false positive)at the beginning of the line and two joined spaces at somepoint in the line 
            findings.append(num)                                      #Adding the line number to the list (helps to manually cross check and to count the lines detechted)
            if short_mode:                                            #If the parameter short_mode is True
                continue                                              #I jump directly to giving the numer of overall findings
            else:
                print(str(num) + ' Line: ' + line)                    #Otherwise, I print the erroneus line including line number to manually cross check 
    print(len(findings))                                              #I print out the overall length of the error list

# %%
def find_SpecSpace_E(year, society, sourcedir, short_mode=True):
    '''
    This function takes the (str)year and (str)society abbreviation as well as a file directory and gives out the number of overall errors in short_mode. 
    In long mode it also shows the erroneus lines that have only spaces between letters and no double spaces between words.
    '''
    
    with open(sourcedir, 'r') as fp:                                  #I open the file as read(!)
        file = fp.readlines()                                         #I copy all lines from the file in a list
    
    findings = []                                                     #an empty list where I collect the line numbers of the error findings
    
    for num, line in enumerate(file, 1):                              #I go through each line of the file-list while also counting the lines starting by 1 instead of 0
        if re.match('^\S\s\S\s', line):                               #I search for the regex marking a none-white space followed by a white space (repeated once to eliminate false positive) at the beginning of the line
            findings.append(num)                                      #Adding the line number to the list (helps to manually cross check and to count the lines detechted)
            if short_mode:                                            #If the parameter short_mode is True
                continue                                              #I jump directly to giving the numer of overall findings
            else:
                print(str(num) + ' Line: ' + line)                    #Otherwise, in long mode I print the erroneus line including line numbers to manually cross check 
    print(len(findings))                                              #I print out the overall length of the error list

# %%
def find_VSpecSpace_E(year, society, sourcedir, short_mode=True):
    '''
    This function takes the (str)year and (str)society abbreviation as well as a file directory and gives out the number of overall errors in short_mode. 
    In long mode it also shows the erroneus lines that have only spaces between letters and no double spaces between words.
    '''
    
    with open(sourcedir, 'r') as fp:                                  #I open the file as read(!)
        file = fp.readlines()                                         #I copy all lines from the file in a list
    
    findings = []                                                     #an empty list where I collect the line numbers of the error findings
    
    for num, line in enumerate(file, 1):                              #I go through each line of the file-list while also counting the lines starting by 1 instead of 0
        if re.search(' \w \w ', line):                               #I search for the regex marking a none-white space followed by a white space (repeated once to eliminate false positive) at the beginning of the line
            findings.append(num)                                      #Adding the line number to the list (helps to manually cross check and to count the lines detechted)
            if short_mode:                                            #If the parameter short_mode is True
                continue                                              #I jump directly to giving the numer of overall findings
            else:
                print(str(num) + ' Line: ' + line)                    #Otherwise, in long mode I print the erroneus line including line numbers to manually cross check 
    print(len(findings))                                              #I print out the overall length of the error list

# %%
def add_Space_E_Stats(year, society, sourcedir):
    '''
    This function takes the (str)year and (str)society abbreviation as well as a file directory 
    and gives out a dictionary with the year, society, number of normal space errors and number of special errors for the given case. 
    The dictionary can be used to be added to an external DataFrame. 
    '''
    
    with open(sourcedir, 'r') as fp:                                 #I open the file as read(!)
        file = fp.readlines()                                        #I copy all lines form the file in a list
    
    nom_space_findings = []                                          #An empty list to store the normal space errors
    spec_space_findings = []                                         #An empty list to store the special space errors           
    
    for num, line in enumerate(file, 1):                             #I loop through all lines while counting them startin from 1 
        if re.match('^\S\s\S\s.*  ', line):                          #I search for the regex for normal space errors (spaces between letters and double spaces between words)
            nom_space_findings.append(num)                           #I append the line number to the empty list
            
        if  re.match('^\S\s\S\s', line):                             #I search for the regex for special space errors (spaces between letters and no double spaces between words)
            spec_space_findings.append(num)                          #I append the line number to an empty list 
    
    return {'YEAR': year, 'SOCIETY': society, 'NUM_NomSpace_ERROR': len(nom_space_findings), 'NUM_SpecSpace_ERROR': len(spec_space_findings)}            #I return a dictionary with the length of the created lists as the values for the Error-keys

# %%
def add_VSpace_E_Stats(year, society, sourcedir):
    '''
    This function takes the (str)year and (str)society abbreviation as well as a file directory 
    and gives out a dictionary with the year, society, number of normal space errors and number of special errors for the given case. 
    The dictionary can be used to be added to an external DataFrame. 
    '''
    
    with open(sourcedir, 'r') as fp:                                 #I open the file as read(!)
        file = fp.readlines()                                        #I copy all lines form the file in a list
    
    findings = []                                                    #An empty list to store the special space errors           
    
    for num, line in enumerate(file, 1):                             #I loop through all lines while counting them startin from 1 
        if re.search(' \w \w ', line):                               #I search for the regex marking a none-white space followed by a white space (repeated once to eliminate false positive) at the beginning of the line
            findings.append(num)                                      #Adding the line number to the list (helps to manually cross check and to count the lines detechted)
      
    
    return {'YEAR': year, 'SOCIETY': society, 'VSpecSpaceE_Start': len(findings)}            #I return a dictionary with the length of the created lists as the values for the Error-keys

# %% [markdown]
# ## Code: Error Stats GEG

# %%
df_GEG = pd.DataFrame()                                                                                         #Without this it gives me an error that df is not defined in index section
df_GEG = pd.DataFrame(index = [len(df_GEG.values)],                                                             #index should count up from 1 to the number of values currently in df
                  columns = ['YEAR', 'SOCIETY', 'NUM_NomSpace_ERROR', 'NUM_SpecSpace_ERROR'])                   #I define the column names

#df_GEG                                                                                                         #I get a blank row index 0 that I will drop later on




ov_md = []                                                                           #An empty list for the overall metadata of my directory 

with open("Sources/GEG/GEGDirectory.txt", "r") as fp:                                #I open I simple .txt file with the names of all files in the folder (created with Git Bash: ls > "file_name.txt" + nano to remove the last line)      
    ov_files = fp.readlines()                                                        #I read all lines in a list
    
    
    for line in ov_files:                                                            #I go through each line/filename in my list
        md = line.split('_')                                                         #I split the filename by "_" to get the year and the name of the society in one list
        ov_md.append(md)                                                             #I add these lists to the overall metadata list 
    
#print(ov_md)
   
    
    

i = 0                                                                                                        #An iterator needed to go through the nested list
for e in ov_md:                                                                                              #I go through each element in the nested list
    year = ov_md[i][0]                                                                                       #I extract the year from the first iteration of every elemented counted by i
    society = ov_md[i][1]                                                                                    #I extract the society name from the second iteration of every elemented counted by i
    sourcedir = 'Sources/' + society + '/' + year + '_' + society + '_SB.txt'                                #I give the source directory needed for the add Function 
    
    new_row_df = pd.DataFrame(add_Space_E_Stats(year, society, sourcedir),                                   #I create a Dataframe for my new row with the data from the add-function             
                          index = [len(df_GEG.values)],                                                      #and the same index and columns as the empty DataFrame
                          columns = ['YEAR', 'SOCIETY', 'NUM_NomSpace_ERROR', 'NUM_SpecSpace_ERROR'])
    df_GEG = pd.concat([df_GEG, new_row_df])                                                                 #I combine the empty DataFrame with the new row Data Frame effectively adding each row.
    i += 1

df_GEG = df_GEG.drop([0])                                                                                     #I remove index 0 
df_GEG
# Out:
#          YEAR SOCIETY NUM_NomSpace_ERROR NUM_SpecSpace_ERROR
# 1        1873     GEG                169                 180
# 2        1874     GEG                 29                  50
# 3        1875     GEG                139                 154
# 4        1876     GEG                 66                  77
# 5        1877     GEG                 99                 115
# 6        1878     GEG                386                 407
# 7        1879     GEG                222                 282
# 8        1880     GEG                233                 271
# 9        1881     GEG                326                 382
# 10       1882     GEG                415                 479
# 11       1883     GEG                222                 259
# 12       1884     GEG                396                 455
# 13       1885     GEG                208                 241
# 14       1886     GEG                325                 371
# ...

# %%
year = '1907'                            
society = 'GEG'                                   
sourcedir = 'Sources/' + society + '/' + year + '_' + society + '_SB.txt'
    
find_NomSpace_E(year, society, sourcedir, short_mode=True)
find_SpecSpace_E(year, society, sourcedir, short_mode=False)
# Out:
# 745
# 9 Line: D r u c k  v o n  C .  M a t t i e s e n .
#
# 21 Line: ; f 'jw •* •#
#
# 25 Line: D r u c k  v o n  С .  M a t t i e s e n .
#
# 32 Line: I n h a l t .
#
# 84 Line: N e k r o l o g e :
#
# 86 Line: P r o f .  D r .  S o p h u s  B u g g e  .  .  .  .  XXII
#
# 87 Line: P a s t o r  D r .  J a k o b  H u r t  .  .  .  .  71—79
#
# 88 Line: P r o f .  A n t o n  v .  M i e r z y n s k i .  .  XXXVIII
#
# 89 Line: G u t s b e s i t z e r  N i k o l a i  W  a l d m a n n  XXXVIII
#
# 107 Line: N a c h s e n d u n g  d e r  S . - B .  1 9 0 4 ) ;  B u c h h a n d l u n g  W .  M e i l i n  u .  K o . ,
#
# 109 Line: N .  K y m m e l ,  R i g a  ( B e s t e l l u n g e n )  ;  P r o f .  W s e w o l .  M i l l e r ,
#
# 121 Line: 1 )  V o m  e t h n o g r a p h i s c h e n  M u s e u m  d e r  K .  A k a ­
#
# 127 Line: 3 )  G o l d s c hm i e d  Th .  B l ume  i n  H i l d e s h e im :  D e r  H i l ­
#
# ...

# %%
#https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_csv.html

filepath = Path('Sources/GEG/2023-02-02_GEGErrorStats.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
df_GEG.to_csv(filepath)

# %% [markdown]
# ## Code: Error Stats GGuA

# %%
#Same for the GEG

df_GGuA = pd.DataFrame()                                                         
df_GGuA = pd.DataFrame(index = [len(df_GGuA.values)], 
                        columns = ['YEAR', 'SOCIETY', 'NUM_NomSpace_ERROR', 'NUM_SpecSpace_ERROR'])   

#df_GGuA

ov_md = []

with open("Sources/GGuA/GGuADirectory.txt", "r") as fp:
    ov_files = fp.readlines()
    
    
    for line in ov_files:
        md = line.split('_')
        ov_md.append(md)
        
#print(ov_md)
        

i = 0
for e in ov_md:
    year = ov_md[i][0]
    society = ov_md[i][1]
    sourcedir = 'Sources/' + society + '/' + year + '_' + society + '_SB.txt'
    
    new_row_df = pd.DataFrame(add_Space_E_Stats(year, society, sourcedir),                                                                                                          
                          index = [len(df_GGuA.values)],                                                
                          columns = ['YEAR', 'SOCIETY', 'NUM_NomSpace_ERROR', 'NUM_SpecSpace_ERROR'])
    df_GGuA = pd.concat([df_GGuA, new_row_df])
    i += 1
        
df_GGuA = df_GGuA.drop([0])
df_GGuA
# Out:
#          YEAR SOCIETY NUM_NomSpace_ERROR NUM_SpecSpace_ERROR
# 1        1873    GGuA                  0                 101
# 2        1874    GGuA                  0                 135
# 3        1875    GGuA                  0                 191
# 4        1876    GGuA                  0                  21
# 5   1877-1881    GGuA                  0                 127
# 6   1882-1883    GGuA                  0                  60
# 7        1884    GGuA                  0                 139
# 8        1885    GGuA                  0                  39
# 9        1886    GGuA                  0                  92
# 10       1887    GGuA                  1                  23
# 11       1888    GGuA                  7                  11
# 12       1889    GGuA                 16                  32
# 13       1890    GGuA                 17                  25
# 14       1891    GGuA                 24                  27
# ...

# %%
year = '1913'
society = 'GGuA'
sourcedir = 'Sources/' + society + '/' + year + '_' + society + '_SB.txt'

find_NomSpace_E(year, society, sourcedir, short_mode=False)
find_SpecSpace_E(year, society, sourcedir, short_mode=False)
# Out:
# 5146 Line: I V . 1 5 1 1 - 1 6 4 0 , n. 1 9 7 — 3 7 0 ( 1 7 3 ) : _10_9 n_n_. =_ _6 3_ _%_.  _8 4_ n_n . _= _77,_01o_/o .
#
# 6212 Line: e s 1 8 e s a s
#
# 6225 Line: a t a s
#
# 3
# 1 Line: г и i . .
#
# 21 Line: I n h a l t s a n z e i g e .
#
# 44 Line: 1 9 1 3 .
#
# 95 Line: o r d n u n g , die von der Versammlung gutgeheissen und bestätigt
#
# 105 Line: L i e v e n : Baltischer Wappenkalender für das Jahr 1902.
#
# 107 Line: A r m i t s t e a d geb. Pychlau aus dem Nachlass von J . W. Armit-
#
# 109 Line: v e n : ein silbernes Jagdbesteck; 3) von Herrn F. Baron v. d.
#
# 110 Line: R e c k e : eine Sammlung alter Schlüssel; 4) von Herrn Wilhelm
#
# 112 Line: W e i n b e r g : ein Knäuelkörbchen und Knäuelhalter aus Masern*
#
# 116 Line: b u s c h : eine vierarmige Öllampe aus Messing, ein zinnernes
#
# 156 Line: C o r n a r i u s , einen Humanisten, der auch in Riga gelebt und
#
# 162 Line: z i n , obwohl er sich ursprünglich der Philologie gewidmet hatte.
#
# ...

# %%
filepath = Path('Sources/GGuA/2023-02-02_GGuAErrorStats.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
df_GGuA.to_csv(filepath)

# %% [markdown]
# ## Code: Error Stats NVR

# %%
#Same for the NVR 

df_NVR = pd.DataFrame()                                                         
df_NVR = pd.DataFrame(index = [len(df_NVR.values)], 
                        columns = ['YEAR', 'SOCIETY', 'NUM_NomSpace_ERROR', 'NUM_SpecSpace_ERROR'])   

#df_NVR

ov_md = []

with open("Sources/NVR/NVRDirectory.txt", "r") as fp:
    ov_files = fp.readlines()
    
    
    for line in ov_files:
        md = line.split('_')
        md_3 = re.sub('\\n', '', md[3])                                                                    #For the NVR I have information on the issue number which is different in every file_name
        md.append(md_3)                                                                                    #I substitute the line break and add the clean version anew
        ov_md.append(md)
        
#print(ov_md)
        

i = 0
for e in ov_md:
    year = ov_md[i][0]
    society = ov_md[i][1]
    num_end = ov_md[i][4]                                                                                  #I take the number and ending of my directory from the fifth position of the nested list
    sourcedir = 'Sources/' + society + '/' + year + '_' + society + '_Cor_' + num_end
    
    new_row_df = pd.DataFrame(add_Space_E_Stats(year, society, sourcedir),                                                                                                          
                          index = [len(df_NVR.values)],                                                
                          columns = ['YEAR', 'SOCIETY', 'NUM_NomSpace_ERROR', 'NUM_SpecSpace_ERROR'])
    df_NVR = pd.concat([df_NVR, new_row_df])
    i += 1

df_NVR = df_NVR.drop([0])
df_NVR
# Out:
#     YEAR SOCIETY NUM_NomSpace_ERROR NUM_SpecSpace_ERROR
# 1   1870     NVR                331                 396
# 2   1872     NVR                450                 580
# 3   1874     NVR                320                 390
# 4   1875     NVR                241                 358
# 5   1877     NVR                455                 559
# 6   1880     NVR                447                 693
# 7   1881     NVR                 99                 255
# 8   1882     NVR                 49                 228
# 9   1883     NVR                 77                 261
# 10  1884     NVR                 74                 341
# 11  1885     NVR                 74                 265
# 12  1886     NVR                 70                 240
# 13  1887     NVR                 61                 230
# 14  1888     NVR                 88                 251
# 15  1889     NVR                 43                 246
# 16  1890     NVR                 19                 133
# ...

# %%
year = '1872'
society = 'NVR'
num_end = '19.txt'                                                                                  
sourcedir = 'Sources/' + society + '/' + year + '_' + society + '_Cor_' + num_end

find_NomSpace_E(year, society, sourcedir, short_mode=False)
find_SpecSpace_E(year, society, sourcedir, short_mode=False)
# Out:
# 4 Line: z u  R i g a .
#
# 8 Line: R e g i s t e r .
#
# 172 Line: S i t z u n g e n  d e s  V e r e i n s .
#
# 174 Line: N a t u r a l i e n .  D e r  D i r e c t o r  z e i g t e  a n ,  d a s s  d i e  a m
#
# 187 Line: „ L i c h e n e n  E s t - ,  L i v -  u n d  K u r l a n d s ,  b e s c h r i e b e n
#
# 188 Line: v o n  A .  B r u t t a n , "  D o r p a t  1 8 7 0 .  H r .  A p o t h e k e r  H e u g e l
#
# 259 Line: P i l z e  . . . .  . 324 r>
#
# 260 Line: A l g e n  . . . .  . 12 r>
#
# 285 Line: d e n  w e i t e s t e n  S p i e l r a u m ,  s o  d a s s  z .  B .  v o n  R a b e n h o r s t
#
# 320 Line: a b t e i l u n g e n  o d e r  S e r i e n  g e s c h i e d e n :  i n  H e t e r  o m e r i s c h e
#
# 332 Line: d i e  d r e i  n a t ü r l i c h e n  O r d n u n g e n  d e r  S t r  a u c h  f l e c h t e n  ( L i e h ,
#
# 360 Line: „ G e o l o g i s c h e r  A u s f l u g  i n  d i e  R u s s i s c h e n  N a c h ­
#
# ...

# %%
filepath = Path('Sources/NVR/2023-07-20_NVRErrorStats.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
df_NVR.to_csv(filepath)

# %% [markdown]
# ## Code: Cleaning NomSpace Errors GEG

# %%
#year = '1873'                            
#society = 'GEG'                                   
#sourcedir = 'Sources/' + society + '/' + year + '_' + society + '_SB.txt' 


#I need the same metadata as before so I use the same code to extract that data from the Directory-file

ov_md = []

with open("Sources/GEG/GEGDirectory.txt", "r") as fp:
    ov_files = fp.readlines()
    
    for line in ov_files:
        md = line.split('_')
        ov_md.append(md)        
#print(ov_md)

i = 0
for e in ov_md:
    year = ov_md[i][0]
    society = ov_md[i][1]
    sourcedir = 'Sources/' + society + '/' + year + '_' + society + '_SB.txt'

    
    
    new_file = []                                                                               #I need an empty list to store the improved text

    with open(sourcedir, 'r') as fp:                                                            #I open the source file
        file = fp.readlines()                                                                   #And read the lines into a file


        for line in file:                                                                       #I go through each line in the file
            if re.match('^\S\s\S\s.*  ', line):                                                 #If a line matches the NomSpaceError pattern
                new_line = re.sub('(\S)\s', r'\1', line)                                        #I substitute each letter followed by a space with only the letter
                new_file.append(new_line)                                                       #I add the new line to the new file list       
            else:                                                                               #If no error is found
                new_file.append(line)                                                           #I add the line directly to the new file         

    #print(new_file)

    outdir = 'Sources/' + society + '/' + year + '_' + society + '_New.txt'                     #I define the output with the same metadata just changening the ending of the file to "New.txt"

    with open(outdir, 'w') as fp:                                                               #I open the outdir to write 
            fp.write("".join(str(item) for item in new_file))                                   #And write into the file the string of each item in new file with no joining element because the lines still include the line break
            
    i += 1                                                                                      #I iterate through the metadata list

# %%
#I use the same code as before but now with a new directory file only including the newly generated .txt files 
#I generate the new directory with the git bash command: ls *New.txt > GEGNewDirectory.txt


df_GEG = pd.DataFrame()                                                                                         
df_GEG = pd.DataFrame(index = [len(df_GEG.values)],                                                            
                  columns = ['YEAR', 'SOCIETY', 'NUM_NomSpace_ERROR', 'NUM_SpecSpace_ERROR'])                

#df_GEG                                                                                                       




ov_md = []                                                                         

with open("Sources/GEG/GEGNewDirectory.txt", "r") as fp:                                   
    ov_files = fp.readlines()                                                   
    
    
    for line in ov_files:                                                    
        md = line.split('_')                                          
        ov_md.append(md)                                                
    
#print(ov_md)
   
    
    

i = 0                                                                                                
for e in ov_md:                                                                              
    year = ov_md[i][0]                                                                                   
    society = ov_md[i][1]                                                                           
    sourcedir = 'Sources/' + society + '/' + year + '_' + society + '_New.txt'                              
    
    new_row_df = pd.DataFrame(add_Space_E_Stats(year, society, sourcedir),                                         
                          index = [len(df_GEG.values)],                                                     
                          columns = ['YEAR', 'SOCIETY', 'NUM_NomSpace_ERROR', 'NUM_SpecSpace_ERROR'])
    df_GEG = pd.concat([df_GEG, new_row_df])                                                                
    i += 1

df_GEG = df_GEG.drop([0])                                                                                   
df_GEG
# Out:
#          YEAR SOCIETY NUM_NomSpace_ERROR NUM_SpecSpace_ERROR
# 1        1873     GEG                  0                  11
# 2        1874     GEG                  0                  21
# 3        1875     GEG                  0                  14
# 4        1876     GEG                  0                  11
# 5        1877     GEG                  0                  14
# 6        1878     GEG                  0                  19
# 7        1879     GEG                  0                  44
# 8        1880     GEG                  0                  27
# 9        1881     GEG                  0                  44
# 10       1882     GEG                  0                  53
# 11       1883     GEG                  0                  34
# 12       1884     GEG                  0                  53
# 13       1885     GEG                  0                  29
# 14       1886     GEG                  0                  38
# ...

# %%
year = '1882'                            
society = 'GEG'                                   
sourcedir = 'Sources/' + society + '/' + year + '_' + society + '_New.txt'

find_SpecSpace_E(year, society, sourcedir, short_mode=False)
# Out:
# 124 Line: — 2 —
#
# 156 Line: — 3 —
#
# 188 Line: — 4 —
#
# 220 Line: — 5 —
#
# 252 Line: - 6 —
#
# 284 Line: — 7 —
#
# 316 Line: — 8 —
#
# 331 Line: L i v e n, über deren gegenwärtigen Bestand die kürz-
#
# 349 Line: — 9 —
#
# 408 Line: d i e herauszuheben, die sich im Gothische n und
#
# 448 Line: m ä t a r „Mutter" und ähnlichen Formen, aber doch
#
# 452 Line: m ö d a r, sondern a i th e i und damit stimmt das
#
# 483 Line: h a 1 (1 a n lautet und so nur vom „Hüten, Weiden",
#
# 495 Line: h a 11 u s „Fels, Stein" zusammen. - Minder
#
# 728 Line: — 2 i —
#
# 734 Line: j o „schon", das im Estnischen sehr gewöhnlich auch
#
# 737 Line: j a „und", das vom Finnischen auch in das Lappische
#
# 895 Line: f e r, gesunden in Pernatt beim Ausgraben des
#
# 991 Line: g e it empfahl der Präsident die Inangriffnahme
#
# 1015 Line: f ü r st e n" gehaltenen Vortrag, in dem unter Ande­
#
# 1038 Line: M ä r d> e it i n Deutscher U e b c r f e tz it it g"
#
# ...

# %%
filepath = Path('Sources/GEG/2023-02-02_GEGNewErrorStats.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
df_GEG.to_csv(filepath)

# %% [markdown]
# ## Code: Cleaning NomSpace Errors GGuA

# %%
#I use the same code as for Cleaning NomSpace Errors GEG 

ov_md = []

with open("Sources/GGuA/GGuADirectory.txt", "r") as fp:                                     #Change to GGuA
    ov_files = fp.readlines()
    
    for line in ov_files:
        md = line.split('_')
        ov_md.append(md)        
#print(ov_md)

i = 0
for e in ov_md:
    year = ov_md[i][0]
    society = ov_md[i][1]
    sourcedir = 'Sources/' + society + '/' + year + '_' + society + '_SB.txt'

    
    
    new_file = []                                                                              

    with open(sourcedir, 'r') as fp:                                                           
        file = fp.readlines()                                                          


        for line in file:                                                             
            if re.match('^\S\s\S\s.*  ', line):                              
                new_line = re.sub('(\S)\s', r'\1', line)                     
                new_file.append(new_line)                                          
            else:                                                  
                new_file.append(line)                                        

    #print(new_file)

    outdir = 'Sources/' + society + '/' + year + '_' + society +'_New.txt'            

    with open(outdir, 'w') as fp:                                               
            fp.write("".join(str(item) for item in new_file))  
            
    i += 1

# %%
#I use the same code as before but now with a new directory file only including the newly generated .txt files 
#I generate the new directory with the git bash command: ls *New.txt > GEGNewDirectory.txt

df_GGuA = pd.DataFrame()                                                         
df_GGuA = pd.DataFrame(index = [len(df_GGuA.values)], 
                        columns = ['YEAR', 'SOCIETY', 'NUM_NomSpace_ERROR', 'NUM_SpecSpace_ERROR'])   

#df_GGuA

ov_md = []

with open("Sources/GGuA/GGuANewDirectory.txt", "r") as fp:                                         #Change to New directory
    ov_files = fp.readlines()
    
    
    for line in ov_files:
        md = line.split('_')
        ov_md.append(md)
        
#print(ov_md)
        

i = 0
for e in ov_md:
    year = ov_md[i][0]
    society = ov_md[i][1]
    sourcedir = 'Sources/' + society + '/' + year + '_' + society + '_New.txt'                          #Change to new files
    
    new_row_df = pd.DataFrame(add_Space_E_Stats(year, society, sourcedir),                                                                                                          
                          index = [len(df_GGuA.values)],                                                
                          columns = ['YEAR', 'SOCIETY', 'NUM_NomSpace_ERROR', 'NUM_SpecSpace_ERROR'])
    df_GGuA = pd.concat([df_GGuA, new_row_df])
    i += 1
        
df_GGuA = df_GGuA.drop([0])
df_GGuA
# Out:
#          YEAR SOCIETY NUM_NomSpace_ERROR NUM_SpecSpace_ERROR
# 1        1873    GGuA                  0                 101
# 2        1874    GGuA                  0                 135
# 3        1875    GGuA                  0                 191
# 4        1876    GGuA                  0                  21
# 5   1877-1881    GGuA                  0                 127
# 6   1882-1883    GGuA                  0                  60
# 7        1884    GGuA                  0                 139
# 8        1885    GGuA                  0                  39
# 9        1886    GGuA                  0                  92
# 10       1887    GGuA                  0                  22
# 11       1888    GGuA                  0                   4
# 12       1889    GGuA                  0                  16
# 13       1890    GGuA                  0                   8
# 14       1891    GGuA                  0                   3
# ...

# %%
year = '1913'                            
society = 'GGuA'                                   
sourcedir = 'Sources/' + society + '/' + year + '_' + society + '_New.txt'

find_SpecSpace_E(year, society, sourcedir, short_mode=False)
# Out:
# 1 Line: г и i . .
#
# 21 Line: I n h a l t s a n z e i g e .
#
# 44 Line: 1 9 1 3 .
#
# 95 Line: o r d n u n g , die von der Versammlung gutgeheissen und bestätigt
#
# 105 Line: L i e v e n : Baltischer Wappenkalender für das Jahr 1902.
#
# 107 Line: A r m i t s t e a d geb. Pychlau aus dem Nachlass von J . W. Armit-
#
# 109 Line: v e n : ein silbernes Jagdbesteck; 3) von Herrn F. Baron v. d.
#
# 110 Line: R e c k e : eine Sammlung alter Schlüssel; 4) von Herrn Wilhelm
#
# 112 Line: W e i n b e r g : ein Knäuelkörbchen und Knäuelhalter aus Masern*
#
# 116 Line: b u s c h : eine vierarmige Öllampe aus Messing, ein zinnernes
#
# 156 Line: C o r n a r i u s , einen Humanisten, der auch in Riga gelebt und
#
# 162 Line: z i n , obwohl er sich ursprünglich der Philologie gewidmet hatte.
#
# 167 Line: R u s s l a u d und L i v l a n d . Dass Cornarius als Arzt in R iga
#
# 229 Line: G r u n d r i s s ist der Bau des Langhauses von dem des Chors
#
# 332 Line: D o m i n D o r p a t .
#
# ...

# %%
filepath = Path('Sources/GGuA/2023-02-02_GGuANewErrorStats.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
df_GGuA.to_csv(filepath)

# %% [markdown]
# ## Code: Cleaning NomSpace Errors NVR

# %%
#I use them same code as for the NVR Error Stats

ov_md = []

with open("Sources/NVR/NVRDirectory.txt", "r") as fp:
    ov_files = fp.readlines()
    
    
    for line in ov_files:
        md = line.split('_')
        md_3 = re.sub('\\n', '', md[3])                                                                    #For the NVR I have information on the issue number which is different in every file_name
        md.append(md_3)                                                                                    #I substitute the line break and add the clean version anew
        ov_md.append(md)
        
#print(ov_md)
        

i = 0
for e in ov_md:
    year = ov_md[i][0]
    society = ov_md[i][1]
    num_end = ov_md[i][4]                                                                                  #I take the number and ending of my directory from the fifth position of the nested list
    sourcedir = 'Sources/' + society + '/' + year + '_' + society + '_Cor_' + num_end
    
    
    new_file = []                                                                              

    with open(sourcedir, 'r') as fp:                                                           
        file = fp.readlines()                                                          


        for line in file:                                                             
            if re.match('^\S\s\S\s.*  ', line):                              
                new_line = re.sub('(\S)\s', r'\1', line)                     
                new_file.append(new_line)                                          
            else:                                                  
                new_file.append(line)                                        

    #print(new_file)

    outdir = 'Sources/' + society + '/' + year + '_' + society + '_New.txt'            

    with open(outdir, 'w') as fp:                                               
            fp.write("".join(str(item) for item in new_file))  
            
    i += 1

# %%
#For individual files

year = "1874"
society = "NVR"
num_end = "20"                                                                                  #I take the number and ending of my directory from the fifth position of the nested list
sourcedir = 'Sources/' + society + '/' + year + '_' + society + '_Cor_' + num_end + ".txt"
    
    
new_file = []                                                                              

with open(sourcedir, 'r') as fp:                                                           
    file = fp.readlines()                                                          


    for line in file:                                                             
        if re.match('^\S\s\S\s.*  ', line):                              
            new_line = re.sub('(\S)\s', r'\1', line)                     
            new_file.append(new_line)                                          
        else:                                                  
            new_file.append(line)                                        

#print(new_file)

# %%
#For individual files

outdir = 'Sources/' + society + '/' + year + '_' + society + '_New.txt'            

with open(outdir, 'w') as fp:                                               
    fp.write("".join(str(item) for item in new_file))

# %%
#I use the same code as before but now with a new directory file only including the newly generated .txt files 
#I generate the new directory with the git bash command: ls *New.txt > NVRNewDirectory.txt

df_NVR = pd.DataFrame()                                                         
df_NVR = pd.DataFrame(index = [len(df_NVR.values)], 
                        columns = ['YEAR', 'SOCIETY', 'NUM_NomSpace_ERROR', 'NUM_SpecSpace_ERROR'])   

#df_NVR

ov_md = []

with open("Sources/NVR/NVRNewDirectory.txt", "r") as fp:
    ov_files = fp.readlines()
    
    
    for line in ov_files:
        md = line.split('_')
        ov_md.append(md)
        
#print(ov_md)
        

i = 0
for e in ov_md:
    year = ov_md[i][0]
    society = ov_md[i][1]
    sourcedir = 'Sources/' + society + '/' + year + '_' + society + '_New.txt'
    
    new_row_df = pd.DataFrame(add_Space_E_Stats(year, society, sourcedir),                                                                                                          
                          index = [len(df_NVR.values)],                                                
                          columns = ['YEAR', 'SOCIETY', 'NUM_NomSpace_ERROR', 'NUM_SpecSpace_ERROR'])
    df_NVR = pd.concat([df_NVR, new_row_df])
    i += 1

df_NVR = df_NVR.drop([0])
df_NVR
# Out:
#     YEAR SOCIETY NUM_NomSpace_ERROR NUM_SpecSpace_ERROR
# 1   1870     NVR                  0                  63
# 2   1872     NVR                  0                 129
# 3   1874     NVR                  0                  70
# 4   1875     NVR                  0                 117
# 5   1877     NVR                  0                 104
# 6   1880     NVR                  0                 246
# 7   1881     NVR                  0                 149
# 8   1882     NVR                  0                 179
# 9   1883     NVR                  0                 184
# 10  1884     NVR                  0                 247
# 11  1885     NVR                  0                 182
# 12  1886     NVR                  0                 169
# 13  1887     NVR                  0                 169
# 14  1888     NVR                  0                 163
# 15  1889     NVR                  0                 203
# 16  1890     NVR                  0                 114
# ...

# %%
year = '1880'
society = 'NVR'                                                                                 
sourcedir = 'Sources/' + society + '/' + year + '_' + society + '_New.txt'

find_SpecSpace_E(year, society, sourcedir, short_mode=False)
# Out:
# 242 Line: — 2 —
#
# 283 Line: - 3 —
#
# 325 Line: 4 —
#
# 401 Line: — 6 —
#
# 441 Line: — 7 —
#
# 518 Line: — 9 —
#
# 702 Line: n ' • Oct. n 0,0 „ 3,o
#
# 764 Line: 1 + 8.7 43.3 84 SW. 2 10 +10.4 + 6.6 R. 19.7 4.7 4.8
#
# 766 Line: 3 + 5.5 62.1 65 NNW.3 7 + 7.3 + 2.9 R. 6.2 5.3 5.0
#
# 767 Line: 4 + 5.6 65.6 79 WSW 2 3 + 9.7 + 1.4 5.3 5.2
#
# 768 Line: 5 + 5.6 61.2 81 0. 0 7 + 8.3 + 2.4 4.3 41
#
# 769 Line: 6 + 4.8 63.8 82 SE. 1 10 + 6.7 + 1.5 4.2 4.2
#
# 770 Line: 7 + 6.2 65.2 87 0. 0 10 + 9.1 + 1.4 3.0 4.4 4.4
#
# 771 Line: 8 + 8.9 58.6 91 S. 2 10 +10.9 + 6.4 R. 9.2 3.9 4.0
#
# 821 Line: ö «
#
# 824 Line: 1 + 1.2 47.2 94 SW. 1 10 + 1.9 + 0.2 RS. 5.6 4.45
#
# 825 Line: 2 + 1.3 53.6 94 SW. 2 10 + 2.9 + 0.3 RS. 1.0 4.8
#
# 826 Line: 3 — 0.2 49.8 96 SSW. 3 10 + 0.3 — 0.5 S. 1.8 4.65
#
# 827 Line: 4 — 0.4 52.4 76 NW. 3 7 + 0.3 — 1.5 S. 5.3 5.65
#
# 828 Line: 5 - 2.7 61.1 81 O. 0 10 1.8 — 4.6 S. 1.4 4.65
#
# 829 Line: 6 — 4.1 64.4 89 S. 1 9 — 1.7 — 8.0 1.2 4.35
#
# ...

# %%
filepath = Path('Sources/NVR/2023-08-31_NVRNomCleanErrorStats.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
df_NVR.to_csv(filepath)

# %% [markdown]
# ## Code: Cleaning SpecSpace Errors GGuA

# %%
ov_md = []

with open("Sources/GGuA/GGuANewDirectory.txt", "r") as fp:                                     
    ov_files = fp.readlines()
    
    for line in ov_files:
        md = line.split('_')
        ov_md.append(md)        
#print(ov_md)

i = 0
for e in ov_md:
    year = ov_md[i][0]
    society = ov_md[i][1]
    sourcedir = 'Sources/' + society + '/' + year + '_' + society + '_New.txt'
       

    V_Spec_Space_Errors = []
    new_file = [] 
    with open(sourcedir, 'r') as fp:                                                           
        file = fp.readlines()                                                          


        for num, line in enumerate(file, 1):                                                            
            if re.match('^\S\s\S\s', line):
                if re.match('^\S\s\S\s.\w\w', line):
                    new_file.append(line)
                    V_Spec_Space_Errors.append(num)
                else:
                    aug_line = re.sub(r'([A-Z])', r' \1', line)
                    new_line = re.sub(r'(\S)\s', r'\1', aug_line)                     
                    new_file.append(new_line)                                          
            else:                                                  
                new_file.append(line)                                        

#print(new_file)
        print(len(V_Spec_Space_Errors))
    
        outdir = 'Sources/' + society + '/' + year + '_' + society +'_New.txt'            

        with open(outdir, 'w') as fp:                                               
            fp.write("".join(str(item) for item in new_file))  
            
        i += 1
# Out:
# 0
# 4
# 4
# 2
# 0
# 5
# 3
# 1
# 4
# 2
# 2
# 1
# 4
# 0
# 0
# 167
# 5
# 2
# 1
# 2
# 1
# 0
# 0
# 2
# 2
# 177
# 24
# 14
# 4
# 16
# 13
# 16
# 26
# 40
# 34
# 257
# 2

# %%
df_GGuA = pd.DataFrame()                                                         
df_GGuA = pd.DataFrame(index = [len(df_GGuA.values)], 
                        columns = ['YEAR', 'SOCIETY', 'NUM_NomSpace_ERROR', 'NUM_SpecSpace_ERROR'])   

#df_GGuA

ov_md = []

with open("Sources/GGuA/GGuANewDirectory.txt", "r") as fp:                                         #Change to New directory
    ov_files = fp.readlines()
    
    
    for line in ov_files:
        md = line.split('_')
        ov_md.append(md)
        
#print(ov_md)
        

i = 0
for e in ov_md:
    year = ov_md[i][0]
    society = ov_md[i][1]
    sourcedir = 'Sources/' + society + '/' + year + '_' + society + '_New.txt'                          #Change to new files
    
    new_row_df = pd.DataFrame(add_Space_E_Stats(year, society, sourcedir),                                                                                                          
                          index = [len(df_GGuA.values)],                                                
                          columns = ['YEAR', 'SOCIETY', 'NUM_NomSpace_ERROR', 'NUM_SpecSpace_ERROR'])
    df_GGuA = pd.concat([df_GGuA, new_row_df])
    i += 1
        
df_GGuA = df_GGuA.drop([0])
df_GGuA
# Out:
#          YEAR SOCIETY NUM_NomSpace_ERROR NUM_SpecSpace_ERROR
# 1        1873    GGuA                  0                   0
# 2        1874    GGuA                  0                   4
# 3        1875    GGuA                  0                   4
# 4        1876    GGuA                  0                   2
# 5   1877-1881    GGuA                  0                   0
# 6   1882-1883    GGuA                  0                   5
# 7        1884    GGuA                  0                   5
# 8        1885    GGuA                  0                   1
# 9        1886    GGuA                  0                   4
# 10       1887    GGuA                  0                   2
# 11       1888    GGuA                  0                   2
# 12       1889    GGuA                  0                   2
# 13       1890    GGuA                  0                   5
# 14       1891    GGuA                  0                   0
# ...

# %%
filepath = Path('Sources/GGuA/2023-02-02_GGuASpecCleanErrorStats.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
df_GGuA.to_csv(filepath)

# %%
year = '1913'                            
society = 'GGuA'                                   
sourcedir = 'Sources/' + society + '/' + year + '_' + society + '_New.txt'
find_SpecSpace_E(year, society, sourcedir, short_mode = False)
# Out:
# 3436 Line: 0 . Stavenhagen-Mitau und Oberlehrer W. Räder-Goldingen
#
# 10079 Line: J . Noribergae 1615; literae Imperatoris 1616; Titulaturen hoher
#
# 11377 Line: — 2 (im Vorjahr 9), und ein anderes Mitglied — eine. Der Rück-
#
# 13678 Line: — — Bitte inbetreff des Einlieferungstermins der für
#
# 13680 Line: — — Zur Frage der Bebauung des Dorpater Domberges 3 f.
#
# 13681 Line: — — Mitteilung über eine Schenkung von Hand-
#
# 13683 Line: — — Mitteilung über die geplante Wiederherstellung
#
# 13685 Line: — — Vorschlag zur Begründung eines „Baltischen Vor-
#
# 13688 Line: — — Mitteilung über den Al lerhöchsten Dank
#
# 13694 Line: — — Glückwunsch im Namen der Gesellschaft zum
#
# 13697 Line: — — Mitteilung über die Beteiligung der Gesellschaft an
#
# 13723 Line: — — Hinweis auf den „Bericht über die Arbeiten im
#
# 13725 Line: — — Dank an Dr. M. Ebert, die Schwestergesell-
#
# 13729 Line: — — Mitteilung über die Adresse der Gesellschaft
#
# ...

# %% [markdown]
# ## Code: Cleaning SpecSpace Errors GEG

# %%
ov_md = []

with open("Sources/GEG/GEGNewDirectory.txt", "r") as fp:
    ov_files = fp.readlines()
    
    for line in ov_files:
        md = line.split('_')
        ov_md.append(md)        
#print(ov_md)

i = 0
for e in ov_md:
    year = ov_md[i][0]
    society = ov_md[i][1]
    sourcedir = 'Sources/' + society + '/' + year + '_' + society + '_New.txt'

    
    
    new_file = []                                                                              

    with open(sourcedir, 'r') as fp:                                                       
        file = fp.readlines()                                                       


        for num, line in enumerate(file, 1):                                                            
            if re.match('^\S\s\S\s', line):
                if re.match('^\S\s\S\s.\w\w', line):
                    new_file.append(line)
                    V_Spec_Space_Errors.append(num)
                else:
                    aug_line = re.sub(r'([A-Z])', r' \1', line)
                    new_line = re.sub(r'(\S)\s', r'\1', aug_line)                     
                    new_file.append(new_line)                                          
            else:                                                  
                new_file.append(line)                                        

#print(new_file)
#print(len(V_Spec_Space_Errors))                  
#print(new_file)

    outdir = 'Sources/' + society + '/' + year + '_' + society + '_New.txt'    

    with open(outdir, 'w') as fp:                                
            fp.write("".join(str(item) for item in new_file))                            
            
    i += 1

# %%
df_GEG = pd.DataFrame()                                                                                         
df_GEG = pd.DataFrame(index = [len(df_GEG.values)],                                                            
                  columns = ['YEAR', 'SOCIETY', 'NUM_NomSpace_ERROR', 'NUM_SpecSpace_ERROR'])                

#df_GEG                                                                                                       




ov_md = []                                                                         

with open("Sources/GEG/GEGNewDirectory.txt", "r") as fp:                                   
    ov_files = fp.readlines()                                                   
    
    
    for line in ov_files:                                                    
        md = line.split('_')                                          
        ov_md.append(md)                                                
    
#print(ov_md)
   
    
    

i = 0                                                                                                
for e in ov_md:                                                                              
    year = ov_md[i][0]                                                                                   
    society = ov_md[i][1]                                                                           
    sourcedir = 'Sources/' + society + '/' + year + '_' + society + '_New.txt'                              
    
    new_row_df = pd.DataFrame(add_Space_E_Stats(year, society, sourcedir),                                         
                          index = [len(df_GEG.values)],                                                     
                          columns = ['YEAR', 'SOCIETY', 'NUM_NomSpace_ERROR', 'NUM_SpecSpace_ERROR'])
    df_GEG = pd.concat([df_GEG, new_row_df])                                                                
    i += 1

df_GEG = df_GEG.drop([0])                                                                                   
df_GEG
# Out:
#          YEAR SOCIETY NUM_NomSpace_ERROR NUM_SpecSpace_ERROR
# 1        1873     GEG                  0                   1
# 2        1874     GEG                  0                   0
# 3        1875     GEG                  0                   0
# 4        1876     GEG                  0                   2
# 5        1877     GEG                  0                   1
# 6        1878     GEG                  0                   3
# 7        1879     GEG                  0                  14
# 8        1880     GEG                  0                   3
# 9        1881     GEG                  0                   4
# 10       1882     GEG                  0                   6
# 11       1883     GEG                  0                   7
# 12       1884     GEG                  0                   4
# 13       1885     GEG                  0                   4
# 14       1886     GEG                  0                   4
# ...

# %%
filepath = Path('Sources/GEG/2023-02-02_GEGSpecCleanErrorStats.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
df_GEG.to_csv(filepath)

# %%
year = '1910'                            
society = 'GEG'                                   
sourcedir = 'Sources/' + society + '/' + year + '_' + society + '_New.txt'
find_SpecSpace_E(year, society, sourcedir, short_mode = False)
# Out:
# 3297 Line: ' I
#
# 4446 Line: 4 )  Vielleicht derselbe, der 1564 zu St. Matthaei Pastor war, s.
#
# 4915 Line: 1 j Btfcfyof СІ?еоЬогіф 1005—46 H-?
#
# 4916 Line: 1 ; 0fyne Btfdjofsnamen. Das (Dmega perfect, ;
#
# 4918 Line: 1 j ïjerjog (Bofelo pon Hicberlotfyringen. 2?edjts2, \
#
# 4920 Line: 1 I Brüffel. HOIVIV Umfcfyriften ganj renml&ert 142 b
#
# 4927 Line: 5 1 ^lanbern, <25raf Balbuin IV 989—1036. 3n
#
# 4929 Line: 6 3 ZTamur, <25raf Gilbert III 1037—1105: 1) AL-
#
# 4935 Line: 7 1 Celles, Kaifer £)еіпгіф III 1036—56, H lig
#
# 4938 Line: 8 1 Bouillon, <5raf <Sottfrieb um 1070. Vot ber
#
# 6152 Line: P a volini übergebe ich der Gesellschaft den stattlichen, 367
#
# 6605 Line: 2 )  Vergl. Abbildung II.
#
# 12

# %% [markdown]
# ## Code: Cleaning SpecSpace Errors NVR

# %%
ov_md = []

with open("Sources/NVR/NVRNewDirectory.txt", "r") as fp:
    ov_files = fp.readlines()
    
    
    for line in ov_files:
        md = line.split('_')
        #md_3 = re.sub('\\n', '', md[3])                                                          
        #md.append(md_3)                                                                
        ov_md.append(md)
        
#print(ov_md)
        

i = 0
for e in ov_md:
    year = ov_md[i][0]
    society = ov_md[i][1]
    #num_end = ov_md[i][4]                                                           
    sourcedir = 'Sources/' + society + '/' + year + '_' + society + '_New.txt'
    
    
    new_file = []                                                                              

    with open(sourcedir, 'r') as fp:                                                           
        file = fp.readlines()                                                          


        for num, line in enumerate(file, 1):                                                            
            if re.match('^\S\s\S\s', line):
                if re.match('^\S\s\S\s.\w\w', line):
                    new_file.append(line)
                    V_Spec_Space_Errors.append(num)
                else:
                    aug_line = re.sub(r'([A-Z])', r' \1', line)
                    new_line = re.sub(r'(\S)\s', r'\1', aug_line)                     
                    new_file.append(new_line)                                          
            else:                                                  
                new_file.append(line)                                        

#print(new_file)
#print(len(V_Spec_Space_Errors))                  
#print(new_file)

    outdir = 'Sources/' + society + '/' + year + '_' + society + '_New.txt'            

    with open(outdir, 'w') as fp:                                               
            fp.write("".join(str(item) for item in new_file))  
            
    i += 1

# %%
#for individual files

year = "1874"
society = "NVR"
sourcedir = 'Sources/' + society + '/' + year + '_' + society + '_New.txt'
    
V_Spec_Space_Errors = []
new_file = []                                                                              

with open(sourcedir, 'r') as fp:                                                           
    file = fp.readlines()                                                          


    for num, line in enumerate(file, 1):                                                            
        if re.match('^\S\s\S\s', line):
            if re.match('^\S\s\S\s.\w\w', line):
                new_file.append(line)
                V_Spec_Space_Errors.append(num)
            else:
                aug_line = re.sub(r'([A-Z])', r' \1', line)
                new_line = re.sub(r'(\S)\s', r'\1', aug_line)                     
                new_file.append(new_line)                                          
        else:                                                  
            new_file.append(line)                                        

#print(new_file)
#print(len(V_Spec_Space_Errors))                  
#print(new_file)

# %%
#for individual files 

outdir = 'Sources/' + society + '/' + year + '_' + society + '_New.txt'            

with open(outdir, 'w') as fp:                                               
        fp.write("".join(str(item) for item in new_file))

# %%
df_NVR = pd.DataFrame()                                                         
df_NVR = pd.DataFrame(index = [len(df_NVR.values)], 
                        columns = ['YEAR', 'SOCIETY', 'NUM_NomSpace_ERROR', 'NUM_SpecSpace_ERROR'])   

#df_NVR

ov_md = []

with open("Sources/NVR/NVRNewDirectory.txt", "r") as fp:
    ov_files = fp.readlines()
    
    
    for line in ov_files:
        md = line.split('_')
        ov_md.append(md)
        
#print(ov_md)
        

i = 0
for e in ov_md:
    year = ov_md[i][0]
    society = ov_md[i][1]
    sourcedir = 'Sources/' + society + '/' + year + '_' + society + '_New.txt'
    
    new_row_df = pd.DataFrame(add_Space_E_Stats(year, society, sourcedir),                                                                                                          
                          index = [len(df_NVR.values)],                                                
                          columns = ['YEAR', 'SOCIETY', 'NUM_NomSpace_ERROR', 'NUM_SpecSpace_ERROR'])
    df_NVR = pd.concat([df_NVR, new_row_df])
    i += 1

df_NVR = df_NVR.drop([0])
df_NVR
# Out:
#     YEAR SOCIETY NUM_NomSpace_ERROR NUM_SpecSpace_ERROR
# 1   1870     NVR                  0                  22
# 2   1872     NVR                  0                  34
# 3   1874     NVR                  0                   8
# 4   1875     NVR                  0                  10
# 5   1877     NVR                  1                   4
# 6   1880     NVR                  0                  14
# 7   1881     NVR                  0                  11
# 8   1882     NVR                  0                   7
# 9   1883     NVR                  0                  14
# 10  1884     NVR                  0                   5
# 11  1885     NVR                  0                  17
# 12  1886     NVR                  0                   6
# 13  1887     NVR                  0                   6
# 14  1888     NVR                  0                   2
# 15  1889     NVR                  0                   6
# 16  1890     NVR                  0                   1
# ...

# %%
filepath = Path('Sources/NVR/2023-08-31_NVRSpecCleanErrorStats.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
df_NVR.to_csv(filepath)

# %%
year = '1885'
society = 'NVR'                                                                                 
sourcedir = 'Sources/' + society + '/' + year + '_' + society + '_New.txt'

find_SpecSpace_E(year, society, sourcedir, short_mode=False)
# Out:
# 155 Line: M e ssu n g :
#
# 224 Line: M e ssu n g :
#
# 1340 Line: A m sterd a m . Akademie der W issenschaften.
#
# 1344 Line: A m ste r d a m . Zoologische Genossenschaft.
#
# 1457 Line: X X III. Bericht 1884.
#
# 2239 Line: % S bФo
#
# 2268 Line: £ N Wmoa CO£ Z ZzHänfigk. 1 1 1 5 10 6 1 9 9 4 1 7 6 2 4 8 12
#
# 2672 Line: 4 +  13.9 50.1 82 ESE. 14 9 — — R. 2.5 4.1
#
# 2674 Line: 6 +  13.9 48.1 84 S. 10 9 —— — R. 4.57 +12.8 53..8 75 WSW. 6 6 — 4.7
#
# 2804 Line: 7 +  15.7 59.6 79 N. 8 3 — — 4.5
#
# 2919 Line: 4 +  17.6 60.0 77 WSW 3 1 — — 4.8
#
# 2920 Line: 5 +  17.3 60.2 91 NW. 4 1 — — R. 4.4 5.2
#
# 3046 Line: 1 +  11.7 58.9 88 NNE. 6 6 _ _и R. 6.1 4.0
#
# 3047 Line: 2 +  12.5 63.6 80 SSE. 6 8 — — 3.9
#
# 3052 Line: 7 +  13.9 60.6 97 NNW. 4 2 — — 3.8
#
# 3108 Line: 5 +  10.3 71.5 87 0 4 +14.1 + 7.0 3.8
#
# 3167 Line: 2 +  11.1 66.1 75 SE. 8 6 — — 4.1
#
# 17

# %% [markdown]
# ## Code: Finding VSpecSpace Errors

# %%
ov_md = []

with open("Sources/NVR/NVRNewDirectory.txt", "r") as fp:
    ov_files = fp.readlines()
    
    for line in ov_files:
        md = line.split('_')
        ov_md.append(md)        
#print(ov_md)

i = 0
for e in ov_md:
    year = ov_md[i][0]
    society = ov_md[i][1]
    sourcedir = 'Sources/' + society + '/' + year + '_' + society + '_New.txt'
    
    print(year)
    find_VSpecSpace_E(year, society, sourcedir, short_mode=True)
    
    i += 1
# Out:
# 1870
# 73
# 1872
# 224
# 1874
# 278
# 1875
# 247
# 1877
# 520
# 1880
# 609
# 1881
# 850
# 1882
# 495
# 1883
# 508
# 1884
# 730
# 1885
# 767
# 1886
# 415
# 1887
# 424
# 1888
# 406
# 1889
# 382
# 1890
# 414
# 1891
# 486
# 1892
# 457
# 1893
# 526
# 1894
# 592
# 1895
# 461
# 1897
# 431
# 1898
# 431
# 1899
# 447
# 1900
# 412
# 1901
# 364
# 1902
# 402
# 1903
# 358
# 1904
# 365
# 1905
# 469
# 1906
# 475
# 1907
# 692
# 1908
# 498
# 1909
# 669
# 1910
# 688
# 1911
# 523
# 1912
# 621
# 1913
# 551
# 1915
# 575
# 1924
# 575

# %%
year = '1872'
society = 'NVR'
sourcedir = 'Sources/' + society + '/' + year + '_' + society + '_New.txt'
    
find_VSpecSpace_E(year, society, sourcedir, short_mode=False)
# Out:
# 21 Line: „  „ i n W i n d a u v o n  1 8 7 0  31. 177.
#
# 83 Line: Kälte, deren Einfluss auf die Vegetation, nach Goeppert . . . .  9 1 .
#
# 113 Line: Pegel und Pegelbeobachtungen . . .  5 8 .  5 9 .  9 3 .  1 3 9 .
#
# 254 Line: Marsileaceen 2 V
#
# 454 Line: 9 'S g a •4^ .
#
# 456 Line: h S03  s S 3 $ £ © © © © a ==
#
# 458 Line: & X X X
#
# 461 Line: Raubvögel 26 8 12 5 1 6 51
#
# 462 Line: Klettervögel 12 5 4 3 — 5 22
#
# 463 Line: Singvögel 66 20 40 5 1 — 25 119
#
# 464 Line: Hühner 9 6 2 — 1 — 3 14
#
# 465 Line: Sumpfvögel 31 23 6 1 1 — 4 42
#
# 466 Line: Schwimmvögel 33 13 13 4 2 2 8 69
#
# 713 Line: 7 NW Häufigkeit . . 3 14 29 23 1 6 10
#
# 714 Line: Mittlere Stärke 1 1 1 2 1 1 2 1
#
# 761 Line: Häufigkeit . . 9 8 5 23 11 1
#
# 762 Line: Mittlere Stärke 1 1 1 2 2 2
#
# 811 Line: 29 2.73 4.53 81.00 70.03 O. 1 5
#
# 816 Line: Häufigkeit . . 7 11 10 26 17 4 4
#
# 817 Line: Mittlere Stärke 2 2 1 2 2 2 3
#
# 1405 Line: Juli . . . (Häufigkt. 6 18 5 5 11 4 33 7 4
#
# ...

# %%
ov_md = []

with open("Sources/GEG/GEGNewDirectory.txt", "r") as fp:
    ov_files = fp.readlines()
    
    for line in ov_files:
        md = line.split('_')
        ov_md.append(md)        
#print(ov_md)

i = 0
for e in ov_md:
    year = ov_md[i][0]
    society = ov_md[i][1]
    sourcedir = 'Sources/' + society + '/' + year + '_' + society + '_New.txt'
    
    print(year)
    find_VSpecSpace_E(year, society, sourcedir, short_mode=True)
    
    i += 1
# Out:
# 1873
# 62
# 1874
# 72
# 1875
# 72
# 1876
# 40
# 1877
# 95
# 1878
# 81
# 1879
# 215
# 1880
# 166
# 1881
# 277
# 1882
# 365
# 1883
# 187
# 1884
# 209
# 1885
# 190
# 1886
# 230
# 1887
# 104
# 1888
# 177
# 1889
# 110
# 1890
# 99
# 1891
# 86
# 1892
# 62
# 1893
# 63
# 1894
# 84
# 1895
# 65
# 1896
# 96
# 1897
# 57
# 1898
# 79
# 1899
# 105
# 1900
# 87
# 1901
# 91
# 1902
# 403
# 1903
# 454
# 1904
# 80
# 1905
# 65
# 1906
# 54
# 1907
# 219
# 1908
# 104
# 1909
# 115
# 1910
# 65
# 1911
# 35
# 1912-1922
# 213

# %%
year = '1911'
society = 'GEG'
sourcedir = 'Sources/' + society + '/' + year + '_' + society + '_New.txt'
    
find_VSpecSpace_E(year, society, sourcedir, short_mode=False)
# Out:
# 133 Line: s) S. В u g g e, Der Runenstein v. Röck. Stockholm 1910.
#
# 146 Line: Sekretär der Gesellschaft, Prof. Max В о eh m in Gebweiler, Ei­
#
# 149 Line: A. A s s m u s s und Pastor Aug. W e s t r é n - D о 11 zu Bartholomäi.
#
# 196 Line: alten Ordensschlosses N y slot (Neuschloss) am Ausflusse der Na-
#
# 269 Line: a) Wilh. N e u m a n n , Merkbüchlein zur Denkmalpflege
#
# 274 Line: c) A. J. v. Hä с к el, Die Trophäen der Kriege 1812—1814,
#
# 337 Line: c) 2 amerikanische Editionen : F. F о w к e г, Antiquities
#
# 360 Line: n) W. S t i e d a, Thüringische Glashütten in der Vergan­
#
# 441 Line: Ehrenmitgliede, Herrn Geh. Rat. Professor Dr. Ludwig S t i e d a
#
# 500 Line: von A11 s a с h e n des 16. Jahrhunderts. S. die Beschreibung in
#
# 531 Line: seine  S c h r i f t  ü b e r  d e n  e s t n i s c h e n  D i a l e k t  d e s  K i r c h s p i e l s  K o d -
#
# 544 Line: d) N. В u s с h, Rhoeadales et Sarraceniales der Kaukasischen
#
# ...

# %%
ov_md = []

with open("Sources/GGuA/GGuANewDirectory.txt", "r") as fp:
    ov_files = fp.readlines()
    
    for line in ov_files:
        md = line.split('_')
        ov_md.append(md)        
#print(ov_md)

i = 0
for e in ov_md:
    year = ov_md[i][0]
    society = ov_md[i][1]
    sourcedir = 'Sources/' + society + '/' + year + '_' + society + '_New.txt'
    
    print(year)
    find_VSpecSpace_E(year, society, sourcedir, short_mode=True)
    
    i += 1
# Out:
# 1873
# 328
# 1874
# 494
# 1875
# 574
# 1876
# 39
# 1877-1881
# 591
# 1882-1883
# 418
# 1884
# 614
# 1885
# 210
# 1886
# 503
# 1887
# 14
# 1888
# 13
# 1889
# 57
# 1890
# 44
# 1891
# 150
# 1892
# 90
# 1893
# 71
# 1894
# 109
# 1895
# 124
# 1896
# 67
# 1897
# 89
# 1898
# 63
# 1899
# 10
# 1900
# 19
# 1901
# 93
# 1902
# 47
# 1903
# 14
# 1904
# 51
# 1905
# 7
# 1906
# 16
# 1907
# 18
# 1908
# 24
# 1909
# 19
# 1910
# 34
# 1911
# 755
# 1912
# 356
# 1913
# 648
# 1914
# 77

# %%
year = '1884'
society = 'GGuA'
sourcedir = 'Sources/' + society + '/' + year + '_' + society + '_New.txt'
    
find_VSpecSpace_E(year, society, sourcedir, short_mode=False)
# Out:
# 4 Line: aus d e m Jahr 1 8 8 4.
#
# 7 Line: Druck von W. F, H a c k e r .
#
# 27 Line: archivar Dr. Th. S c h i e m a n n in Reval: Th. Schiemann.
#
# 29 Line: Stadtarchivar, Archivrath Dr. F. P h i l i p p i zu Königsberg:
#
# 34 Line: Landesgymnasiums zu Fellin, Herrn Staatsrath H. S e e s e -
#
# 38 Line: nasiums zu Goldingen, Herrn Staatsrath A. B ü t t n e r :
#
# 41 Line: von Herrn Dr. G e o r g Dehio zu Königsberg: G. Deh io ,
#
# 43 Line: Herrn V i c t o r D i e d e r i c h s : V. Diederichs, Die kurische
#
# 45 Line: Bibliothekar wirkl. Staatsrath Dr. Chr. F r . v. W a l t h e r
#
# 88 Line: aufgenommen Pastor E d u a r d v. B e r g m a n n zu Süd-Rujen
#
# 90 Line: Herr Baron H. B r u i n i n g k legte der Versammlung
#
# 98 Line: nasial-Director K r a u s e in Rostock" zugeschickt und von
#
# 125 Line: reformator N i c o l a u s Rus eingesandt, welche von dem
#
# 150 Line: Ketzer wegeführet,. nach R i g a gefahren." 1550 ist er
#
# ...

# %% [markdown]
# ## Code: Combining Stats GEG

# %%
#I need NomSpaceE from 'Sources/GEG/2023-02-01_GEGErrorStats.csv'
# SpecSpaceE from 'Sources/GEG/2023-02-02_GEGNomCleanErrorStats.csv'
# ReSpecSpaceE (remaining Errors) from 'Sources/GEG/2023-02-09_GEGSpecCleanErrorStats.csv'
# VSpecSpaceE from the function directly 

df_GEG = pd.read_csv('Sources/GEG/2023-02-01_GEGErrorStats.csv')
df_GEG = df_GEG.drop(columns=['Unnamed: 0', 'NUM_SpecSpace_ERROR'])

df1 = pd.read_csv('Sources/GEG/2023-02-02_GEGNomCleanErrorStats.csv')

df_GEG = pd.merge(df_GEG, df1, how="left", on="YEAR")
df_GEG = df_GEG.drop(columns=['Unnamed: 0', 'SOCIETY_y'])

df_GEG = df_GEG.rename(columns={"SOCIETY_x":"SOCIETY", "NUM_NomSpace_ERROR_x":"NomSpaceE_Start", "NUM_NomSpace_ERROR_y":"NomSpaceE_End","NUM_SpecSpace_ERROR" : "SpecSpaceE_Start"})

df2 = pd.read_csv('Sources/GEG/2023-02-09_GEGSpecCleanErrorStats.csv')

df_GEG = pd.merge(df_GEG, df2, how="left", on="YEAR")
df_GEG = df_GEG.drop(columns=['Unnamed: 0', 'SOCIETY_y', 'NUM_NomSpace_ERROR'])
df_GEG = df_GEG.rename(columns={"SOCIETY_x":"SOCIETY", "NUM_SpecSpace_ERROR" : "SpecSpaceE_End"})

df_GEG
# Out:
#          YEAR SOCIETY  NomSpaceE_Start  NomSpaceE_End  SpecSpaceE_Start  \
# 0        1873     GEG              169              0                11
# 1        1874     GEG               29              0                21
# 2        1875     GEG              139              0                14
# 3        1876     GEG               66              0                11
# 4        1877     GEG               99              0                14
# 5        1878     GEG              386              0                19
# 6        1879     GEG              222              0                44
# 7        1880     GEG              233              0                27
# 8        1881     GEG              326              0                44
# 9        1882     GEG              415              0                53
# 10       1883     GEG              222              0                34
# 11       1884     GEG              396              0                53
# ...

# %%
df_VSSE = pd.DataFrame()                                                                                         
df_VSSE= pd.DataFrame(index = [len(df_VSSE.values)],                                                            
                  columns = ['YEAR', 'SOCIETY', 'VSpecSpaceE_Start'])                

ov_md = []                                                                         

with open("Sources/GEG/GEGNewDirectory.txt", "r") as fp:                                   
    ov_files = fp.readlines()                                                   
    
    
    for line in ov_files:                                                    
        md = line.split('_')                                          
        ov_md.append(md)                                                
    

i = 0                                                                                                
for e in ov_md:                                                                              
    year = ov_md[i][0]                                                                                   
    society = ov_md[i][1]                                                                           
    sourcedir = 'Sources/' + society + '/' + year + '_' + society + '_New.txt'                              
    
    new_row_df = pd.DataFrame(add_VSpace_E_Stats(year, society, sourcedir),                                         
                          index = [len(df_VSSE.values)],                                                     
                          columns = ['YEAR', 'SOCIETY', 'VSpecSpaceE_Start'])
    df_VSSE = pd.concat([df_VSSE, new_row_df])                                                                
    i += 1

df_VSSE = df_VSSE.drop([0])
df_VSSE
# Out:
#          YEAR SOCIETY VSpecSpaceE_Start
# 1        1873     GEG                62
# 2        1874     GEG                72
# 3        1875     GEG                72
# 4        1876     GEG                40
# 5        1877     GEG                95
# 6        1878     GEG                81
# 7        1879     GEG               215
# 8        1880     GEG               166
# 9        1881     GEG               277
# 10       1882     GEG               365
# 11       1883     GEG               187
# 12       1884     GEG               209
# 13       1885     GEG               190
# 14       1886     GEG               230
# 15       1887     GEG               104
# 16       1888     GEG               177
# 17       1889     GEG               110
# 18       1890     GEG                99
# 19       1891     GEG                86
# 20       1892     GEG                62
# 21       1893     GEG                63
# 22       1894     GEG                84
# ...

# %%
df_GEG = pd.merge(df_GEG, df_VSSE, how="left", on="YEAR")

# %%
df_GEG = df_GEG.drop(columns=['SOCIETY_y'])

# %%
df_GEG = df_GEG.rename(columns={"SOCIETY_x":"SOCIETY"})
df_GEG
# Out:
#          YEAR SOCIETY  NomSpaceE_Start  NomSpaceE_End  SpecSpaceE_Start  \
# 0        1873     GEG              169              0                11
# 1        1874     GEG               29              0                21
# 2        1875     GEG              139              0                14
# 3        1876     GEG               66              0                11
# 4        1877     GEG               99              0                14
# 5        1878     GEG              386              0                19
# 6        1879     GEG              222              0                44
# 7        1880     GEG              233              0                27
# 8        1881     GEG              326              0                44
# 9        1882     GEG              415              0                53
# 10       1883     GEG              222              0                34
# 11       1884     GEG              396              0                53
# ...

# %%
df_GEG.dtypes
# Out:
# YEAR                  object
# SOCIETY               object
# NomSpaceE_Start      float64
# NomSpaceE_End        float64
# SpecSpaceE_Start     float64
# SpecSpaceE_End       float64
# VSpecSpaceE_Start     object
# dtype: object

# %%
#https://stackoverflow.com/questions/15891038/change-column-type-in-pandas
df_GEG = df_GEG.astype({"VSpecSpaceE_Start": float})
df_GEG
# Out:
#          YEAR SOCIETY  NomSpaceE_Start  NomSpaceE_End  SpecSpaceE_Start  \
# 0        1873     GEG              169              0                11
# 1        1874     GEG               29              0                21
# 2        1875     GEG              139              0                14
# 3        1876     GEG               66              0                11
# 4        1877     GEG               99              0                14
# 5        1878     GEG              386              0                19
# 6        1879     GEG              222              0                44
# 7        1880     GEG              233              0                27
# 8        1881     GEG              326              0                44
# 9        1882     GEG              415              0                53
# 10       1883     GEG              222              0                34
# 11       1884     GEG              396              0                53
# ...

# %%
#https://stackoverflow.com/questions/41286569/get-total-of-pandas-column
df_GEG.loc['total'] = df_GEG.select_dtypes(np.number).sum()
df_GEG
# Out:
#             YEAR SOCIETY  NomSpaceE_Start  NomSpaceE_End  SpecSpaceE_Start  \
# 0           1873     GEG            169.0            0.0              11.0
# 1           1874     GEG             29.0            0.0              21.0
# 2           1875     GEG            139.0            0.0              14.0
# 3           1876     GEG             66.0            0.0              11.0
# 4           1877     GEG             99.0            0.0              14.0
# 5           1878     GEG            386.0            0.0              19.0
# 6           1879     GEG            222.0            0.0              44.0
# 7           1880     GEG            233.0            0.0              27.0
# 8           1881     GEG            326.0            0.0              44.0
# 9           1882     GEG            415.0            0.0              53.0
# 10          1883     GEG            222.0            0.0              34.0
# ...

# %%
filepath = Path('Sources/GEG/2023-02-13_OverallGEGErrorStats.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
df_GEG.to_csv(filepath)

# %% [markdown]
# ## Code: Combining Stats GGuA

# %%
#I need NomSpaceE from 'Sources/GGuA/2023-02-01_GGuAErrorStats.csv'
# SpecSpaceE from 'Sources/GGuA/2023-02-02_GGuANomCleanErrorStats.csv'
# ReSpecSpaceE (remaining Errors) from 'Sources/GGuA/2023-02-09_GGuASpecCleanErrorStats.csv'
# VSpecSpaceE from the function directly 

df_GGuA = pd.read_csv('Sources/GGuA/2023-02-01_GGuAErrorStats.csv')
df_GGuA = df_GGuA.drop(columns=['Unnamed: 0', 'NUM_SpecSpace_ERROR'])

df1 = pd.read_csv('Sources/GGuA/2023-02-02_GGuANomCleanErrorStats.csv')

df_GGuA = pd.merge(df_GGuA, df1, how="left", on="YEAR")
df_GGuA = df_GGuA.drop(columns=['Unnamed: 0', 'SOCIETY_y'])

df_GGuA = df_GGuA.rename(columns={"SOCIETY_x":"SOCIETY", "NUM_NomSpace_ERROR_x":"NomSpaceE_Start", "NUM_NomSpace_ERROR_y":"NomSpaceE_End","NUM_SpecSpace_ERROR" : "SpecSpaceE_Start"})

df2 = pd.read_csv('Sources/GGuA/2023-02-09_GGuASpecCleanErrorStats.csv')

df_GGuA = pd.merge(df_GGuA, df2, how="left", on="YEAR")
df_GGuA = df_GGuA.drop(columns=['Unnamed: 0', 'SOCIETY_y', 'NUM_NomSpace_ERROR'])
df_GGuA = df_GGuA.rename(columns={"SOCIETY_x":"SOCIETY", "NUM_SpecSpace_ERROR" : "SpecSpaceE_End"})

df_GGuA
# Out:
#          YEAR SOCIETY  NomSpaceE_Start  NomSpaceE_End  SpecSpaceE_Start  \
# 0        1873    GGuA                0              0               101
# 1        1874    GGuA                0              0               135
# 2        1875    GGuA                0              0               191
# 3        1876    GGuA                0              0                21
# 4   1877-1881    GGuA                0              0               127
# 5   1882-1883    GGuA                0              0                60
# 6        1884    GGuA                0              0               139
# 7        1885    GGuA                0              0                39
# 8        1886    GGuA                0              0                92
# 9        1887    GGuA                1              0                22
# 10       1888    GGuA                7              0                 4
# 11       1889    GGuA               16              0                16
# ...

# %%
df_VSSE = pd.DataFrame()                                                                                         
df_VSSE= pd.DataFrame(index = [len(df_VSSE.values)],                                                            
                  columns = ['YEAR', 'SOCIETY', 'VSpecSpaceE_Start'])                

ov_md = []                                                                         

with open("Sources/GGuA/GGuANewDirectory.txt", "r") as fp:                                   
    ov_files = fp.readlines()                                                   
    
    
    for line in ov_files:                                                    
        md = line.split('_')                                          
        ov_md.append(md)                                                
    

i = 0                                                                                                
for e in ov_md:                                                                              
    year = ov_md[i][0]                                                                                   
    society = ov_md[i][1]                                                                           
    sourcedir = 'Sources/' + society + '/' + year + '_' + society + '_New.txt'                              
    
    new_row_df = pd.DataFrame(add_VSpace_E_Stats(year, society, sourcedir),                                         
                          index = [len(df_VSSE.values)],                                                     
                          columns = ['YEAR', 'SOCIETY', 'VSpecSpaceE_Start'])
    df_VSSE = pd.concat([df_VSSE, new_row_df])                                                                
    i += 1

df_VSSE = df_VSSE.drop([0])
df_VSSE
# Out:
#          YEAR SOCIETY VSpecSpaceE_Start
# 1        1873    GGuA               328
# 2        1874    GGuA               494
# 3        1875    GGuA               574
# 4        1876    GGuA                39
# 5   1877-1881    GGuA               591
# 6   1882-1883    GGuA               418
# 7        1884    GGuA               614
# 8        1885    GGuA               210
# 9        1886    GGuA               503
# 10       1887    GGuA                14
# 11       1888    GGuA                13
# 12       1889    GGuA                57
# 13       1890    GGuA                44
# 14       1891    GGuA               150
# 15       1892    GGuA                90
# 16       1893    GGuA                71
# 17       1894    GGuA               109
# 18       1895    GGuA               124
# 19       1896    GGuA                67
# 20       1897    GGuA                89
# 21       1898    GGuA                63
# 22       1899    GGuA                10
# ...

# %%
df_GGuA = pd.merge(df_GGuA, df_VSSE, how="left", on="YEAR")
df_GGuA = df_GGuA.drop(columns=['SOCIETY_y'])
df_GGuA = df_GGuA.rename(columns={"SOCIETY_x":"SOCIETY"})
df_GGuA
# Out:
#          YEAR SOCIETY  NomSpaceE_Start  NomSpaceE_End  SpecSpaceE_Start  \
# 0        1873    GGuA                0              0               101
# 1        1874    GGuA                0              0               135
# 2        1875    GGuA                0              0               191
# 3        1876    GGuA                0              0                21
# 4   1877-1881    GGuA                0              0               127
# 5   1882-1883    GGuA                0              0                60
# 6        1884    GGuA                0              0               139
# 7        1885    GGuA                0              0                39
# 8        1886    GGuA                0              0                92
# 9        1887    GGuA                1              0                22
# 10       1888    GGuA                7              0                 4
# 11       1889    GGuA               16              0                16
# ...

# %%
df_GGuA = df_GGuA.astype({"VSpecSpaceE_Start": float})
#df_GGuA

# %%
df_GGuA.loc['total'] = df_GGuA.select_dtypes(np.number).sum()
df_GGuA
# Out:
#             YEAR SOCIETY  NomSpaceE_Start  NomSpaceE_End  SpecSpaceE_Start  \
# 0           1873    GGuA              0.0            0.0             101.0
# 1           1874    GGuA              0.0            0.0             135.0
# 2           1875    GGuA              0.0            0.0             191.0
# 3           1876    GGuA              0.0            0.0              21.0
# 4      1877-1881    GGuA              0.0            0.0             127.0
# 5      1882-1883    GGuA              0.0            0.0              60.0
# 6           1884    GGuA              0.0            0.0             139.0
# 7           1885    GGuA              0.0            0.0              39.0
# 8           1886    GGuA              0.0            0.0              92.0
# 9           1887    GGuA              1.0            0.0              22.0
# 10          1888    GGuA              7.0            0.0               4.0
# ...

# %%
filepath = Path('Sources/GGuA/2023-02-13_OverallGGuAErrorStats.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
df_GGuA.to_csv(filepath)

# %% [markdown]
# ## Code: Combining Stats NVR

# %%
#I need NomSpaceE from 'Sources/NVR/2023-02-01_NVRErrorStats.csv'
# SpecSpaceE from 'Sources/NVR/2023-02-02_NVRNomCleanErrorStats.csv'
# ReSpecSpaceE (remaining Errors) from 'Sources/NVR/2023-02-09_NVRSpecCleanErrorStats.csv'
# VSpecSpaceE from the function directly 

df_NVR_1 = pd.read_csv('Sources/NVR/2023-07-20_NVRErrorStats.csv')
df_NVR_1 = df_NVR_1.drop(columns=['Unnamed: 0', "NUM_SpecSpace_ERROR"])
df_NVR_1 = df_NVR_1.rename(columns={'NUM_NomSpace_ERROR': "NomSpaceE_Start"})
df_NVR_1
# Out:
#     YEAR SOCIETY  NomSpaceE_Start
# 0   1870     NVR              331
# 1   1872     NVR              450
# 2   1874     NVR              320
# 3   1875     NVR              241
# 4   1877     NVR              455
# 5   1880     NVR              447
# 6   1881     NVR               99
# 7   1882     NVR               49
# 8   1883     NVR               77
# 9   1884     NVR               74
# 10  1885     NVR               74
# 11  1886     NVR               70
# 12  1887     NVR               61
# 13  1888     NVR               88
# 14  1889     NVR               43
# 15  1890     NVR               19
# 16  1891     NVR               86
# 17  1892     NVR               33
# 18  1893     NVR               56
# 19  1894     NVR               94
# 20  1895     NVR              232
# 21  1897     NVR              192
# 22  1898     NVR              192
# 23  1899     NVR              103
# 24  1900     NVR              229
# 25  1901     NVR              111
# ...

# %%
df_NVR_2 = pd.read_csv('Sources/NVR/2023-08-31_NVRNomCleanErrorStats.csv')

#df_NVR = pd.merge(df_NVR, df1, how="left", on="YEAR")
df_NVR_2 = df_NVR_2.drop(columns=['Unnamed: 0', 'SOCIETY'])
df_NVR_2 = df_NVR_2.rename(columns={'NUM_NomSpace_ERROR': "NomSpaceE_End", "NUM_SpecSpace_ERROR" : "SpecSpaceE_Start"})
df_NVR_2
# Out:
#     YEAR  NomSpaceE_End  SpecSpaceE_Start
# 0   1870              0                63
# 1   1872              0               129
# 2   1874              0                70
# 3   1875              0               117
# 4   1877              0               104
# 5   1880              0               246
# 6   1881              0               149
# 7   1882              0               179
# 8   1883              0               184
# 9   1884              0               247
# 10  1885              0               182
# 11  1886              0               169
# 12  1887              0               169
# 13  1888              0               163
# 14  1889              0               203
# 15  1890              0               114
# 16  1891              0                86
# 17  1892              0               109
# 18  1893              0               105
# 19  1894              0                82
# 20  1895              0                57
# ...

# %%
#df_NVR = df_NVR.rename(columns={"SOCIETY_x":"SOCIETY", "NUM_NomSpace_ERROR_x":"NomSpaceE_Start", "NUM_NomSpace_ERROR_y":"NomSpaceE_End"})

df_NVR_3 = pd.read_csv('Sources/NVR/2023-08-31_NVRSpecCleanErrorStats.csv')

df_NVR_3 = df_NVR_3.drop(columns=['Unnamed: 0', 'SOCIETY', 'NUM_NomSpace_ERROR'])
df_NVR_3 = df_NVR_3.rename(columns={"NUM_SpecSpace_ERROR" : "SpecSpaceE_End"})

df_NVR_3
# Out:
#     YEAR  SpecSpaceE_End
# 0   1870              22
# 1   1872              34
# 2   1874               8
# 3   1875              10
# 4   1877               4
# 5   1880              14
# 6   1881              11
# 7   1882               7
# 8   1883              14
# 9   1884               5
# 10  1885              17
# 11  1886               6
# 12  1887               6
# 13  1888               2
# 14  1889               6
# 15  1890               1
# 16  1891               2
# 17  1892               9
# 18  1893               0
# 19  1894              14
# 20  1895              10
# 21  1897               3
# 22  1898               3
# 23  1899              11
# 24  1900              14
# 25  1901               2
# 26  1902               0
# 27  1903               2
# 28  1904              22
# 29  1905              41
# 30  1906              13
# 31  1907              16
# 32  1908               7
# 33  1909              23
# 34  1910               9
# 35  1911              11
# ...

# %%
df_NVR = pd.merge(df_NVR_1, df_NVR_2, how="left", on="YEAR") 
df_NVR = pd.merge(df_NVR, df_NVR_3, how="left", on="YEAR")
df_NVR
# Out:
#     YEAR SOCIETY  NomSpaceE_Start  NomSpaceE_End  SpecSpaceE_Start
# 0   1870     NVR              331              0                63  \
# 1   1872     NVR              450              0               129
# 2   1874     NVR              320              0                70
# 3   1875     NVR              241              0               117
# 4   1877     NVR              455              0               104
# 5   1880     NVR              447              0               246
# 6   1881     NVR               99              0               149
# 7   1882     NVR               49              0               179
# 8   1883     NVR               77              0               184
# 9   1884     NVR               74              0               247
# 10  1885     NVR               74              0               182
# 11  1886     NVR               70              0               169
# 12  1887     NVR               61              0               169
# ...

# %%
df_VSSE = pd.DataFrame()                                                                                         
df_VSSE = pd.DataFrame(index = [len(df_VSSE.values)],                                                            
                  columns = ['YEAR', 'SOCIETY', 'VSpecSpaceE_Start'])                

ov_md = []                                                                         

with open("Sources/NVR/NVRNewDirectory.txt", "r") as fp:                                   
    ov_files = fp.readlines()                                                   
    
    
    for line in ov_files:                                                    
        md = line.split('_')                                          
        ov_md.append(md)                                                
    

i = 0                                                                                                
for e in ov_md:                                                                              
    year = ov_md[i][0]                                                                                   
    society = ov_md[i][1]                                                                           
    sourcedir = 'Sources/' + society + '/' + year + '_' + society + '_New.txt'                              
    
    new_row_df = pd.DataFrame(add_VSpace_E_Stats(year, society, sourcedir),                                         
                          index = [len(df_VSSE.values)],                                                     
                          columns = ['YEAR', 'SOCIETY', 'VSpecSpaceE_Start'])
    df_VSSE = pd.concat([df_VSSE, new_row_df])                                                                
    i += 1

df_VSSE = df_VSSE.drop([0])
df_VSSE
# Out:
#     YEAR SOCIETY VSpecSpaceE_Start
# 1   1870     NVR                73
# 2   1872     NVR               224
# 3   1874     NVR               278
# 4   1875     NVR               247
# 5   1877     NVR               520
# 6   1880     NVR               609
# 7   1881     NVR               850
# 8   1882     NVR               495
# 9   1883     NVR               508
# 10  1884     NVR               730
# 11  1885     NVR               767
# 12  1886     NVR               415
# 13  1887     NVR               424
# 14  1888     NVR               406
# 15  1889     NVR               382
# 16  1890     NVR               414
# 17  1891     NVR               486
# 18  1892     NVR               457
# 19  1893     NVR               526
# 20  1894     NVR               592
# 21  1895     NVR               461
# 22  1897     NVR               431
# 23  1898     NVR               431
# 24  1899     NVR               447
# 25  1900     NVR               412
# 26  1901     NVR               364
# ...

# %%
df_VSSE = df_VSSE.astype({"VSpecSpaceE_Start": int})
df_VSSE = df_VSSE.astype({"YEAR": str})
df_VSSE.dtypes
# Out:
# YEAR                 object
# SOCIETY              object
# VSpecSpaceE_Start     int64
# dtype: object

# %%
#df_VSSE

# %%
df_NVR = df_NVR.astype({"YEAR": str})
df_NVR.dtypes
# Out:
# YEAR                object
# SOCIETY             object
# NomSpaceE_Start      int64
# NomSpaceE_End        int64
# SpecSpaceE_Start     int64
# SpecSpaceE_End       int64
# dtype: object

# %%
df_NVR = pd.merge(df_NVR, df_VSSE, how="left", on="YEAR")
df_NVR = df_NVR.drop(columns=['SOCIETY_y'])
df_NVR = df_NVR.rename(columns={"SOCIETY_x":"SOCIETY"})

df_NVR
# Out:
#     YEAR SOCIETY  NomSpaceE_Start  NomSpaceE_End  SpecSpaceE_Start
# 0   1870     NVR              331              0                63  \
# 1   1872     NVR              450              0               129
# 2   1874     NVR              320              0                70
# 3   1875     NVR              241              0               117
# 4   1877     NVR              455              0               104
# 5   1880     NVR              447              0               246
# 6   1881     NVR               99              0               149
# 7   1882     NVR               49              0               179
# 8   1883     NVR               77              0               184
# 9   1884     NVR               74              0               247
# 10  1885     NVR               74              0               182
# 11  1886     NVR               70              0               169
# 12  1887     NVR               61              0               169
# ...

# %%
df_NVR.loc['total'] = df_NVR.select_dtypes(np.number).sum()
df_NVR
# Out:
#        YEAR SOCIETY  NomSpaceE_Start  NomSpaceE_End  SpecSpaceE_Start
# 0      1870     NVR            331.0            0.0              63.0  \
# 1      1872     NVR            450.0            0.0             129.0
# 2      1874     NVR            320.0            0.0              70.0
# 3      1875     NVR            241.0            0.0             117.0
# 4      1877     NVR            455.0            0.0             104.0
# 5      1880     NVR            447.0            0.0             246.0
# 6      1881     NVR             99.0            0.0             149.0
# 7      1882     NVR             49.0            0.0             179.0
# 8      1883     NVR             77.0            0.0             184.0
# 9      1884     NVR             74.0            0.0             247.0
# 10     1885     NVR             74.0            0.0             182.0
# 11     1886     NVR             70.0            0.0             169.0
# ...

# %%
filepath = Path('Sources/NVR/2023-08-31_OverallNVRErrorStats.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
df_NVR.to_csv(filepath)
